# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
data1 = pd.read_csv('data_one.csv')
data1
# Out:
#             X          y
# 0   -2.000000   6.764052
# 1   -1.991984   5.428213
# 2   -1.983968   6.034850
# 3   -1.975952   7.325062
# 4   -1.967936   6.979782
# ..        ...        ...
# 495  1.967936  18.813851
# 496  1.975952  18.257279
# 497  1.983968  18.429654
# 498  1.991984  17.953902
# 499  2.000000  18.922145
#
# [500 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data1['X'], data1['y'], color='blue')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# y절편을 찾기위해 X데이터의 첫번째 열에 모두 1을 추가

# %%
X = data1['X'].values.reshape(-1, 1)
Y = data1['y'].values.reshape(-1, 1)

ones = np.ones((X.shape[0], 1))
X = np.concatenate((ones, X), axis=1)

X[:5]
# Out:
# array([[ 1.        , -2.        ],
#        [ 1.        , -1.99198397],
#        [ 1.        , -1.98396794],
#        [ 1.        , -1.9759519 ],
#        [ 1.        , -1.96793587]])

# %% [markdown]
# ## Normal Equation

# %%
theta = np.linalg.inv(X.T @ X) @ X.T @ Y
print(theta)
# Out:
# [[11.97464556]
#  [ 3.44579601]]

# %% [markdown]
# ## Gradient Descent Rule로 $\theta ^*$ 찾기

# %%
eta = 0.001
n_iterations = 100000
m = 500


for iteration in range(n_iterations):
    gradients = 2/m * X.T @ (X @ theta - Y)
    theta = theta - eta * gradients
    
print(theta)
# Out:
# [[11.97464556]
#  [ 3.44579601]]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data1['X'], data1['y'], color='b')
plt.plot(X, theta1*X + theta0, color='r')
